# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sas

# %%
df=pd.read_excel(r'C:\Users\dumindu yasa\Desktop\sdgp\DS\EWPS.xlsx')
print (df)
# Out:
#        Unnamed: 0       JobNo  suffix                     ItemCode ColorGroup  \
# 0               0  1900010101       0         FW380049-015BK-0010E        NaN
# 1               2  1900010101       0         FW380049-015BK-0010E        NaN
# 2               3  1900010101       0         FW380049-015BK-0010E        NaN
# 3               4  1900010101       1                 FW380049-015        NaN
# 4               5  1900010101       2  BMY-FW380049-015-51000016-F        NaN
# ...           ...         ...     ...                          ...        ...
# 52274       65495  B204050102       0                 FW380471-032        NaN
# 52275       65496  B204050102       1  BMY-FW380471-032-51000016-F        NaN
# 52276       65497  B204050102       2  BMY-FW380471-032-51000016-B        NaN
# 52277       65498  B204050102       3  BMY-FW380471-032-51000016-S        NaN
# 52278       65499  B204050102       4  BMR-FW380471-032-FDCY000020        NaN
#
# ...

# %%
df[df.MtrWgt!=0.00 ]
# Out:
#        Unnamed: 0       JobNo  suffix           ItemCode ColorGroup  UoM  \
# 3               4  1900010101       1       FW380049-015        NaN  Kgs
# 13             20  1900010201       1       FW380049-015        NaN  Kgs
# 20             28  1900010202       1       FW380049-015        NaN  Kgs
# 27             39  1900010301       1       FW380049-015        NaN  Kgs
# 31             46  1900010302       1       FW380049-015        NaN  Kgs
# ...           ...         ...     ...                ...        ...  ...
# 52260       65478  B204020101       0  FK028082-012BK/GR        NaN  Kgs
# 52261       65479  B204020101       0  FK028082-012BK/GR        NaN  Kgs
# 52264       65482  B204030101       0  FK028082-012BK/GR        NaN  Kgs
# 52269       65489  B204050101       0       FW380471-032        NaN  Kgs
# 52274       65495  B204050102       0       FW380471-032        NaN  Kgs
#
#        QtyCom  QtyScrp      WC  MtrWgt
# 3      123.29     8.79  F2_JAC    7.33
# ...

# %%
df[df.WC=='F1_KNT' ][df.MtrWgt==0.00]
# Out:
# <ipython-input-22-68545a64f958>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.WC=='F1_KNT' ][df.MtrWgt==0.00]
#      Unnamed: 0       JobNo  suffix       ItemCode ColorGroup  UoM  QtyCom  \
# 236         284  1900141001       1  FKS380028-008        NaN  Kgs     1.0
#
#      QtyScrp      WC  MtrWgt
# 236      0.0  F1_KNT     0.0

# %%
df=df[df.JobNo!=1900141001]

# %%
df.to_excel("EWPS_2.xlsx",
             sheet_name='Sheet_name_1')
