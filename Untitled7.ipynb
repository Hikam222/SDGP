# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn.metrics import mean_absolute_error
import joblib

# %%
df=pd.read_excel(r'C:\Users\dumindu yasa\Desktop\sdgp\DS\EWPS_BasicSortFinsh.xlsx')

# %%
df
# Out:
#        Unnamed: 0       JobNo     ItemCode1 ColorGroup    PK_QtyCom  \
# 0               0  1900010101  FW380049-015        NaN  1091.405184
# 1               1  1900010102  FW380049-015        NaN   954.979536
# 2               2  1900010201  FW380049-015        NaN  1637.107776
# 3               3  1900010202  FW380049-015        NaN   954.979536
# 4               4  1900010301  FW380049-015  DYE_SG_LT  1705.320600
# ...           ...         ...           ...        ...          ...
# 11327       11898  B190500302  FW380084-030        NaN   196.270854
# 11328       11899  B190500303  FW380084-030        NaN   560.165168
# 11329       11901  B190520101  FK380075-016  DYE_SG_FI  2045.454545
# 11330       11907  B190570101  FK380052-008        NaN   132.841328
# 11331       11911  B190600201  FK380052-008        NaN   426.199262
#
#        PK_QtyScrp    QA_QtyCom  QA_QtyScrp   DYE_QtyCom  DYE_QtyScrp  ...  \
# 0       29.195089  1116.717446         0.0  1116.717446          0.0  ...
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#             JobNo     ItemCode1 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...        ...          ...         ...
# 11327  B190500302  FW380084-030        NaN   196.270854    0.000000
# 11328  B190500303  FW380084-030        NaN   560.165168    0.000000
# 11329  B190520101  FK380075-016  DYE_SG_FI  2045.454545    0.000000
# 11330  B190570101  FK380052-008        NaN   132.841328    0.000000
# 11331  B190600201  FK380052-008        NaN   426.199262    0.000000
#
#          QA_QtyCom  QA_QtyScrp   DYE_QtyCom  DYE_QtyScrp  KNT_QtyCom  \
# 0      1116.717446         0.0  1116.717446          0.0        0.00
# ...

# %%
df["Total_Wastage"]=df["PK_QtyScrp"]+df["QA_QtyScrp"]+df["DYE_QtyScrp"]+df["KNT_QtyScrp"]+df["WEV_QtyScrp"]+df["WP_QtyScrp"]+df["JAC_QtyScrp"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a041db2e997> in <module>
# ----> 1 df["Total_Wastage"]=df["PK_QtyScrp"]+df["QA_QtyScrp"]+df["DYE_QtyScrp"]+df["KNT_QtyScrp"]+df["WEV_QtyScrp"]+df["WP_QtyScrp"]+df["JAC_QtyScrp"]
#
# NameError: name 'df' is not defined
