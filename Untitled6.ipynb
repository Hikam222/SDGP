# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sas
from numpy.random import randint

# %%
df=pd.read_excel(r'C:\Users\dumindu yasa\Desktop\sdgp\DS\EWPS_part2.xlsx')

# %%
df
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16354  B204050105  FW380471-032       NaN        NaN     0.000000    0.000000
# 16355  B204060101  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16356  B204060102  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16357  B204060103  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16358  B204060201  FJ086519-038       /GR        NaN     0.000000    0.000000
#
# ...

# %%
print(df.head(3))
# Out:
#         JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0  1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1  1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2  1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
#
#      QA_QtyCom  QA_QtyScrp   DYE_QtyCom  DYE_QtyScrp  KNT_QtyCom  KNT_QtyScrp  \
# 0  1116.717446         0.0  1116.717446          0.0         0.0          0.0
# 1  1060.982265         0.0  1060.982265          0.0         0.0          0.0
# 2  1823.874488         0.0  3031.650750          0.0         0.0          0.0
#
#    WEV_QtyCom  WEV_QtyScrp  WP_QtyCom  WP_QtyScrp  JAC_QtyCom  JAC_QtyScrp
# 0        0.00         0.00      77.80         0.0      123.29         8.79
# 1        0.00         0.00       0.00         0.0        0.00         0.00
# 2      171.15         9.23     140.77         0.0        0.00         0.00

# %%
df2=df.ItemCode1.value_counts()

# %%
print(df2.tail(131))
# Out:
# FW380106-030    5
# FK380581-006    4
# FK380051-052    4
# FW380172-013    4
# FK103919-060    4
#                ..
# FK380111-004    1
# FR000002-010    1
# FW380001-014    1
# FW380186-030    1
# FW002784-010    1
# Name: ItemCode1, Length: 131, dtype: int64

# %%
dfjoblist=df

# %%
dfjoblist
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16354  B204050105  FW380471-032       NaN        NaN     0.000000    0.000000
# 16355  B204060101  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16356  B204060102  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16357  B204060103  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16358  B204060201  FJ086519-038       /GR        NaN     0.000000    0.000000
#
# ...

# %%
mylist = []

for index1, row1 in dfjoblist.head(n=16359).iterrows():
    mylist.append(row1.ItemCode1)

        
mylist = list(dict.fromkeys(mylist))
print(mylist)
# Out:
# ['FW380049-015', 'FW380033-010', 'FW380050-016', 'FW380106-025', 'FK380086-040', 'FW380080-030', 'FW380135-025', 'FW380001-018', 'FK380078-08.', 'FW380026-014', 'FK380028-008', 'FJ380091-035', 'FK380075-024', 'FW380072-015', 'FW380072-012', 'FW380072-018', 'FW380016-016', 'FW380016-018', 'FK380087-032', 'FK380097-005', 'FW380084-030', 'FK380037-017', 'FW380071-006', 'FK380056-006', 'FW380044-008', 'FW380009-019', 'FK380068-020', 'FK380038-011', 'FW380009-032', 'FK380132-045', 'FK380075-006', 'FW380063-015', 'FW380144-016', 'FW380143-012', 'FK380118-035', 'FK380118-040', 'FK054594-015', 'FW051849-007', 'FK048204-008', 'FK054595-008', 'FJ101980-032', 'FK380079-020', 'FK380123-013', 'FW380065-006', 'FW380008-025', 'FK380111-006', 'FK380051-060', 'FK380051-056', 'FK380136-056', 'FK380141-045', 'FK380051-058', 'FK380124-024', 'FW380126-008', 'FK380087-040', 'FK380039-08.', 'FK380002-007', 'FK380052-008', 'FW380034-015', 'FW380032-016', 'FW380032-025', 'FW380031-025', 'FK380070-009', 'FW38
# ...

# %%
x = len(mylist)

# %%
print(x)
# Out:
# 440

# %%
for i in mylist:
    r=0;
    print(i)
    df=df[df['JobNo']!=i]
# Out:
# 19-002-R01
# 19003801R1
# 19003901R1
# 1900451402
# 1901061201
# 1901061203
# 1901061301
# 1901061302
# 1901390901
# 1901420101
# 1901420201
# 1901420301
# 1902030101
# 1902640502
# 1903190201
# 1903191201
# 1903200101
# 1903200201
# 1903420301
# 1903440102
# 1903521001
# 1903760701
# 1903980301
# 1903980302
# 1903980303
# 1903980401
# 1904110103
# 1904140201
# 1904140301
# 1904691201
# 1904700301
# 1905071105
# 1905071201
# 1905120301
# 1905130201
# 1905140101
# 1905140401
# 1905140501
# 1905150101
# 1905250101
# 1905540103
# 1905540104
# 1905540106
# 1905580703
# 1905581104
# 1905630101
# 1905770303
# 1905810701
# 1905870402
# 1905900101
# 1905900103
# 1905910102
# 1906001201
# 1906120101
# 1906120201
# 1906230101
# 1906230102
# 1906230201
# 1906230202
# 1906260101
# 1906371201
# 1906374701
# 1906374801
# 1906390102
# 1906410103
# 1906410104
# 1906410105
# 1906410106
# 1906410107
# 1906410108
# 1906410109
# 1906410110
# 1906410207
# 1906410208
# 1906410209
# 1906410210
# ...

# %%
df
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16346  B204010101  FW380509-015       NaN        NaN     0.000000    0.000000
# 16347  B204020101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16348  B204030101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16350  B204050101  FW380471-032       NaN        NaN     0.000000    0.000000
# 16351  B204050102  FW380471-032       NaN        NaN     0.000000    0.000000
#
# ...

# %%
dfjoblist=df[df['PK_QtyCom']==0.0][df['QA_QtyCom']==0.0][df['DYE_QtyCom']==0.0][df['KNT_QtyCom']==0.0][df['WEV_QtyCom']==0.0][df['WP_QtyCom']==0.0][df['JAC_QtyCom']==0.0]
# Out:
# <ipython-input-109-1c0233c65316>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfjoblist=df[df['PK_QtyCom']==0.0][df['QA_QtyCom']==0.0][df['DYE_QtyCom']==0.0][df['KNT_QtyCom']==0.0][df['WEV_QtyCom']==0.0][df['WP_QtyCom']==0.0][df['JAC_QtyCom']==0.0]
# <ipython-input-109-1c0233c65316>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfjoblist=df[df['PK_QtyCom']==0.0][df['QA_QtyCom']==0.0][df['DYE_QtyCom']==0.0][df['KNT_QtyCom']==0.0][df['WEV_QtyCom']==0.0][df['WP_QtyCom']==0.0][df['JAC_QtyCom']==0.0]
# <ipython-input-109-1c0233c65316>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dfjoblist=df[df['PK_QtyCom']==0.0][df['QA_QtyCom']==0.0][df['DYE_QtyCom']==0.0][df['KNT_QtyCom']==0.0][df['WEV_QtyCom']==0.0][df['WP_QtyCom']==0.0][df['JAC_QtyCom']==0.0]
# <ipython-input-109-1c0233c65316>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
dfjoblist
# Out:
# Empty DataFrame
# Columns: [JobNo, ItemCode1, ItemCode2, ColorGroup, PK_QtyCom, PK_QtyScrp, QA_QtyCom, QA_QtyScrp, DYE_QtyCom, DYE_QtyScrp, KNT_QtyCom, KNT_QtyScrp, WEV_QtyCom, WEV_QtyScrp, WP_QtyCom, WP_QtyScrp, JAC_QtyCom, JAC_QtyScrp]
# Index: []

# %%
df
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16354  B204050105  FW380471-032       NaN        NaN     0.000000    0.000000
# 16355  B204060101  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16356  B204060102  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16357  B204060103  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16358  B204060201  FJ086519-038       /GR        NaN     0.000000    0.000000
#
# ...

# %%
mylistyet = []

for index1, row1 in df.head(n=13497).iterrows():
    mylist.append(row1.ItemCode1)

        
mylist = list(dict.fromkeys(mylist))
print(mylist)
# Out:
# ['19-002-R01', '19003801R1', '19003901R1', '1900451402', '1901061201', '1901061203', '1901061301', '1901061302', '1901390901', '1901420101', '1901420201', '1901420301', '1902030101', '1902640502', '1903190201', '1903191201', '1903200101', '1903200201', '1903420301', '1903440102', '1903521001', '1903760701', '1903980301', '1903980302', '1903980303', '1903980401', '1904110103', '1904140201', '1904140301', '1904691201', '1904700301', '1905071105', '1905071201', '1905120301', '1905130201', '1905140101', '1905140401', '1905140501', '1905150101', '1905250101', '1905540103', '1905540104', '1905540106', '1905580703', '1905581104', '1905630101', '1905770303', '1905810701', '1905870402', '1905900101', '1905900103', '1905910102', '1906001201', '1906120101', '1906120201', '1906230101', '1906230102', '1906230201', '1906230202', '1906260101', '1906371201', '1906374701', '1906374801', '1906390102', '1906410103', '1906410104', '1906410105', '1906410106', '1906410107', '1906410108', '1906410109', '19
# ...

# %%
mylist13=[]

# %%
print()

# %%
mylist123=[]

# %%
for i in mylist:
    r=0
    print(i)
    for index1, row1 in df[df.ItemCode1==i].iterrows():
        r=r+1
    if(r<35):
        mylist123.append(i)
# Out:
# FW380049-015
# FW380033-010
# FW380050-016
# FW380106-025
# FK380086-040
# FW380080-030
# FW380135-025
# FW380001-018
# FK380078-08.
# FW380026-014
# FK380028-008
# FJ380091-035
# FK380075-024
# FW380072-015
# FW380072-012
# FW380072-018
# FW380016-016
# FW380016-018
# FK380087-032
# FK380097-005
# FW380084-030
# FK380037-017
# FW380071-006
# FK380056-006
# FW380044-008
# FW380009-019
# FK380068-020
# FK380038-011
# FW380009-032
# FK380132-045
# FK380075-006
# FW380063-015
# FW380144-016
# FW380143-012
# FK380118-035
# FK380118-040
# FK054594-015
# FW051849-007
# FK048204-008
# FK054595-008
# FJ101980-032
# FK380079-020
# FK380123-013
# FW380065-006
# FW380008-025
# FK380111-006
# FK380051-060
# FK380051-056
# FK380136-056
# FK380141-045
# FK380051-058
# FK380124-024
# FW380126-008
# FK380087-040
# FK380039-08.
# FK380002-007
# FK380052-008
# FW380034-015
# FW380032-016
# FW380032-025
# FW380031-025
# FK380070-009
# FW380001-020
# FW380127-019
# FW380000-019
# FW380031-019
# ...

# %%
dfx21=df

# %%
dfx21=df[df.ItemCode1==1]

# %%
dfx21
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16354  B204050105  FW380471-032       NaN        NaN     0.000000    0.000000
# 16355  B204060101  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16356  B204060102  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16357  B204060103  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16358  B204060201  FJ086519-038       /GR        NaN     0.000000    0.000000
#
# ...

# %%
mylist123
# Out:
# ['FW380033-010',
#  'FW380050-016',
#  'FW380106-025',
#  'FK380086-040',
#  'FW380080-030',
#  'FW380135-025',
#  'FK380078-08.',
#  'FJ380091-035',
#  'FK380075-024',
#  'FW380016-016',
#  'FW380016-018',
#  'FK380097-005',
#  'FK380037-017',
#  'FW380071-006',
#  'FK380056-006',
#  'FW380044-008',
#  'FW380009-019',
#  'FK380068-020',
#  'FK380132-045',
#  'FK380075-006',
#  'FW380063-015',
#  'FW380144-016',
#  'FW380143-012',
#  'FK380118-035',
#  'FK380079-020',
#  'FW380065-006',
#  'FK380051-060',
#  'FK380051-056',
#  'FK380136-056',
#  'FK380141-045',
#  'FK380124-024',
#  'FK380087-040',
#  'FW380032-016',
#  'FW380032-025',
#  'FW380031-025',
#  'FW380001-020',
#  'FW380127-019',
#  'FW380000-019',
#  'FW380031-019',
#  'FW380031-022',
#  'FW380125-019',
#  'FW380104-013',
#  'FW380004-020',
#  'FW380103-010',
#  'FW380003-011',
#  'FW380000-025',
#  'FW380095-010',
#  'FW380095-013',
#  'FW380134-032',
#  'FW380064-012',
#  'FK380087-030',
#  'FK380077-006',
# ...

# %%
len(mylist123)
# Out:
# 348

# %%
len(mylist)
# Out:
# 440

# %%
for i in mylist123:
    
    print(i)
    dfx21=dfx21[dfx21.ItemCode1!=i]
# Out:
# FW380033-010
# FW380050-016
# FW380106-025
# FK380086-040
# FW380080-030
# FW380135-025
# FK380078-08.
# FJ380091-035
# FK380075-024
# FW380016-016
# FW380016-018
# FK380097-005
# FK380037-017
# FW380071-006
# FK380056-006
# FW380044-008
# FW380009-019
# FK380068-020
# FK380132-045
# FK380075-006
# FW380063-015
# FW380144-016
# FW380143-012
# FK380118-035
# FK380079-020
# FW380065-006
# FK380051-060
# FK380051-056
# FK380136-056
# FK380141-045
# FK380124-024
# FK380087-040
# FW380032-016
# FW380032-025
# FW380031-025
# FW380001-020
# FW380127-019
# FW380000-019
# FW380031-019
# FW380031-022
# FW380125-019
# FW380104-013
# FW380004-020
# FW380103-010
# FW380003-011
# FW380000-025
# FW380095-010
# FW380095-013
# FW380134-032
# FW380064-012
# FK380087-030
# FK380077-006
# FK380075-026
# FW102976-050
# FK380141-038
# FK380087-038
# FK380121-023
# FW380157-030
# FK380014-006
# FWT380153-02
# FK380090-025
# FK380087-024
# FW380074-010
# FW380084-035
# FW380105-050
# FW380000-016
# ...

# %%
dfx21
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16350  B204050101  FW380471-032       NaN        NaN     0.000000    0.000000
# 16351  B204050102  FW380471-032       NaN        NaN     0.000000    0.000000
# 16352  B204050103  FW380471-032       NaN        NaN     0.000000    0.000000
# 16353  B204050104  FW380471-032       NaN        NaN     0.000000    0.000000
# 16354  B204050105  FW380471-032       NaN        NaN     0.000000    0.000000
#
# ...

# %%
dfx21[dfx21.ItemCode1=="FW380050-016"]
# Out:
# Empty DataFrame
# Columns: [JobNo, ItemCode1, ItemCode2, ColorGroup, PK_QtyCom, PK_QtyScrp, QA_QtyCom, QA_QtyScrp, DYE_QtyCom, DYE_QtyScrp, KNT_QtyCom, KNT_QtyScrp, WEV_QtyCom, WEV_QtyScrp, WP_QtyCom, WP_QtyScrp, JAC_QtyCom, JAC_QtyScrp]
# Index: []

# %%
df
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16354  B204050105  FW380471-032       NaN        NaN     0.000000    0.000000
# 16355  B204060101  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16356  B204060102  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16357  B204060103  FJ086559-038       /GR        NaN     0.000000    0.000000
# 16358  B204060201  FJ086519-038       /GR        NaN     0.000000    0.000000
#
# ...

# %%
for i in mylist:
    r=0
    print(i)
    for index1, row1 in df[df.ItemCode1==i].iterrows():
        r=r+1
    if(r<4):
        mylist13.append(i)
# Out:
# 19-002-R01
# 19003801R1
# 19003901R1
# 1900451402
# 1901061201
# 1901061203
# 1901061301
# 1901061302
# 1901390901
# 1901420101
# 1901420201
# 1901420301
# 1902030101
# 1902640502
# 1903190201
# 1903191201
# 1903200101
# 1903200201
# 1903420301
# 1903440102
# 1903521001
# 1903760701
# 1903980301
# 1903980302
# 1903980303
# 1903980401
# 1904110103
# 1904140201
# 1904140301
# 1904691201
# 1904700301
# 1905071105
# 1905071201
# 1905120301
# 1905130201
# 1905140101
# 1905140401
# 1905140501
# 1905150101
# 1905250101
# 1905540103
# 1905540104
# 1905540106
# 1905580703
# 1905581104
# 1905630101
# 1905770303
# 1905810701
# 1905870402
# 1905900101
# 1905900103
# 1905910102
# 1906001201
# 1906120101
# 1906120201
# 1906230101
# 1906230102
# 1906230201
# 1906230202
# 1906260101
# 1906371201
# 1906374701
# 1906374801
# 1906390102
# 1906410103
# 1906410104
# 1906410105
# 1906410106
# 1906410107
# 1906410108
# 1906410109
# 1906410110
# 1906410207
# 1906410208
# 1906410209
# 1906410210
# ...

# %%
len(mylist13)
# Out:
# 2960

# %%
drt1.head(60)
# Out:
# FK380075-008    3
# FK028082-035    3
# FW380000-022    3
# FW380616-003    3
# FK380068-020    3
# FK028082-045    3
# FK380041-009    3
# FJ380174-050    3
# FW380184-008    3
# FK380090-025    3
# FW380397-045    3
# FW380172-010    3
# FW380312-023    3
# FK380075-015    3
# FW100333-020    3
# FK380087-020    3
# FK380374-029    3
# FW380106-032    3
# FW100028-012    3
# FW100028-016    3
# FW380000-016    3
# FW380032-025    3
# FW380162-030    3
# FJ380477-020    3
# FW380106-038    3
# FW105506-003    3
# FK380374-038    3
# FF102155-012    3
# FK380042-013    3
# FW380143-012    3
# FW100639-020    2
# FK380298-030    2
# FW380113-010    2
# FW380455-015    2
# FW380032-019    2
# FK380069-013    2
# FW380074-009    2
# FK380221-024    2
# FK040176-025    2
# FK380575-013    2
# FW380143-014    2
# FK380069-006    2
# FK380043-010    2
# FK380075-024    2
# FK380575-048    2
# FJ101777-018    2
# FW041854-008    2
# FK380575-050    2
# FWT380153-02    2
# FK380695-020    2
# ...

# %%
df
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16346  B204010101  FW380509-015       NaN        NaN     0.000000    0.000000
# 16347  B204020101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16348  B204030101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16350  B204050101  FW380471-032       NaN        NaN     0.000000    0.000000
# 16351  B204050102  FW380471-032       NaN        NaN     0.000000    0.000000
#
# ...

# %%
dfelastic=df.ItemCode1.value_counts()

# %%
dfelastic
# Out:
# FK380028-008    1733
# FK048204-008    1582
# FW380026-014     770
# FK380334-010     322
# FK380052-008     275
#                 ...
# FW002007-012       1
# FW380186-030       1
# FW380001-014       1
# FK380575-035       1
# FK380193-028       1
# Name: ItemCode1, Length: 416, dtype: int64

# %%
dfelastic.head(100)
# Out:
# FK380028-008    1733
# FK048204-008    1582
# FW380026-014     770
# FK380334-010     322
# FK380052-008     275
#                 ...
# FW050580-007      28
# FW380084-035      28
# FW380084-030      28
# FK380037-017      27
# FK380334-008      27
# Name: ItemCode1, Length: 100, dtype: int64

# %%
dfelastic.head(200)
# Out:
# FK380028-008    1733
# FK048204-008    1582
# FW380026-014     770
# FK380334-010     322
# FK380052-008     275
#                 ...
# FW380557-006      11
# FW380161-015      11
# FK380402-045      10
# FW380085-010      10
# FW380114-010      10
# Name: ItemCode1, Length: 200, dtype: int64

# %%
dfelastic.head(300)
# Out:
# FK380028-008    1733
# FK048204-008    1582
# FW380026-014     770
# FK380334-010     322
# FK380052-008     275
#                 ...
# FK380401-054       4
# FK380087- 03       4
# FK380402-070       4
# FW380509-015       4
# FK380087-024       4
# Name: ItemCode1, Length: 300, dtype: int64

# %%
list1=[]

# %%
for index1, row1 in df.head(n=13497).iterrows():
    mylist.append(row1.ItemCode1)
        
        
list1 = list(dict.fromkeys(mylist))

# %%
mylistyet = []

for index1, row1 in df.head(n=13497).iterrows():
    mylist.append(row1.ItemCode1)

        
mylist = list(dict.fromkeys(mylist))
print(mylist)

# %%
print(list1)
# Out:
# ['19-002-R01', '19003801R1', '19003901R1', '1900451402', '1901061201', '1901061203', '1901061301', '1901061302', '1901390901', '1901420101', '1901420201', '1901420301', '1902030101', '1902640502', '1903190201', '1903191201', '1903200101', '1903200201', '1903420301', '1903440102', '1903521001', '1903760701', '1903980301', '1903980302', '1903980303', '1903980401', '1904110103', '1904140201', '1904140301', '1904691201', '1904700301', '1905071105', '1905071201', '1905120301', '1905130201', '1905140101', '1905140401', '1905140501', '1905150101', '1905250101', '1905540103', '1905540104', '1905540106', '1905580703', '1905581104', '1905630101', '1905770303', '1905810701', '1905870402', '1905900101', '1905900103', '1905910102', '1906001201', '1906120101', '1906120201', '1906230101', '1906230102', '1906230201', '1906230202', '1906260101', '1906371201', '1906374701', '1906374801', '1906390102', '1906410103', '1906410104', '1906410105', '1906410106', '1906410107', '1906410108', '1906410109', '19
# ...

# %%
df
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16346  B204010101  FW380509-015       NaN        NaN     0.000000    0.000000
# 16347  B204020101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16348  B204030101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16350  B204050101  FW380471-032       NaN        NaN     0.000000    0.000000
# 16351  B204050102  FW380471-032       NaN        NaN     0.000000    0.000000
#
# ...

# %%
df.to_excel("EWPS_beforelecture.xlsx",sheet_name='Sheet_name_1')

# %%
drt1.tail(60)
# Out:
# FK380575-048    2
# FJ101777-018    2
# FW041854-008    2
# FK380575-050    2
# FWT380153-02    2
# FK380695-020    2
# FK380618-008    2
# FK380075-020    2
# FW380144-016    2
# FK028082-020    2
# FK380141-045    2
# FK028082-040    2
# FW380697-035    2
# FW100028-010    2
# FK380575-028    2
# FK380120-054    2
# FK380457-030    2
# FK380695-040    2
# FK380075-040    1
# FJ380696-035    1
# FJ380651-036    1
# FK380090-035    1
# FK380208-009    1
# FK380636-010    1
# FK380204-035    1
# FR000001-025    1
# FW049052-012    1
# FK380087-028    1
# FW380134-032    1
# FK380193-028    1
# FJ380489-035    1
# FW380031-025    1
# FK380636-015    1
# FK380014-006    1
# FJ103669-036    1
# FK380056-010    1
# FK380111-004    1
# FWS380114-01    1
# FW048171-006    1
# FK380607-020    1
# FK380331-008    1
# FJ103290-036    1
# FK380141-035    1
# FJ103289-036    1
# FW002007-012    1
# FK380132-045    1
# FK028082-030    1
# FD380272-GD-    1
# FW380186-030    1
# FK380575-035    1
# ...

# %%
objectcode = ["FK380075-008","FK028082-035","FW380000-022","FW380616-003","FK380068-020","FK028082-045","FK380041-009","FJ380174-050","FW380184-008","FK380090-025","FW380397-045","FW380172-010","FW380312-023","FK380075-015","FW100333-020","FK380087-020","FK380374-029","FW380106-032","FW100028-012","FW100028-016","FW380000-016","FW380032-025","FW380162-030","FJ380477-020","FW380106-038","FW105506-003","FK380374-038","FF102155-012","FK380042-013","FW380143-012","FW100639-020","FK380298-030","FW380113-010","FW380455-015","FW380032-019","FK380069-013","FW380074-009","FK380221-024","FK040176-025","FK380575-013","FW380143-014","FK380069-006","FK380043-010","FK380075-024","FK380575-048","FJ101777-018","FW041854-008","FK380575-050","FWT380153-02","FK380695-020","FK380618-008","FK380075-020","FW380144-016","FK028082-020","FK380141-045","FK028082-040","FW380697-035","FW100028-010","FK380575-028","FK380120-054","FK380457-030","FK380695-040","FK380075-040","FJ380696-035","FJ380651-036","FK380090-035","FK380208-009","FK380636-010","FK380204-035","FR000001-025","FW049052-012","FK380087-028","FW380134-032","FK380193-028","FJ380489-035","FW380031-025","FK380636-015","FK380014-006","FJ103669-036","FK380056-010","FK380111-004","FWS380114-01","FW048171-006","FK380607-020","FK380331-008","FJ103290-036","FK380141-035","FJ103289-036","FW002007-012","FK380132-045","FK028082-030","FD380272-GD-","FW380186-030","FK380575-035","FW380448-008","FW380001-014","FR000002-010","FW002784-010","FK028082-019","FWS380034-01","FK380402-035","FW380455-013","FK380457-020","FK380122-004"]

# %%
len(objectcode)
# Out:
# 104

# %%
for i in objectcode:
    r=0;
    print(i)
    df=df[df['ItemCode1']!=i]
# Out:
# FK380075-008
# FK028082-035
# FW380000-022
# FW380616-003
# FK380068-020
# FK028082-045
# FK380041-009
# FJ380174-050
# FW380184-008
# FK380090-025
# FW380397-045
# FW380172-010
# FW380312-023
# FK380075-015
# FW100333-020
# FK380087-020
# FK380374-029
# FW380106-032
# FW100028-012
# FW100028-016
# FW380000-016
# FW380032-025
# FW380162-030
# FJ380477-020
# FW380106-038
# FW105506-003
# FK380374-038
# FF102155-012
# FK380042-013
# FW380143-012
# FW100639-020
# FK380298-030
# FW380113-010
# FW380455-015
# FW380032-019
# FK380069-013
# FW380074-009
# FK380221-024
# FK040176-025
# FK380575-013
# FW380143-014
# FK380069-006
# FK380043-010
# FK380075-024
# FK380575-048
# FJ101777-018
# FW041854-008
# FK380575-050
# FWT380153-02
# FK380695-020
# FK380618-008
# FK380075-020
# FW380144-016
# FK028082-020
# FK380141-045
# FK028082-040
# FW380697-035
# FW100028-010
# FK380575-028
# FK380120-054
# FK380457-030
# FK380695-040
# FK380075-040
# FJ380696-035
# FJ380651-036
# FK380090-035
# ...

# %%
df
# Out:
#             JobNo     ItemCode1 ItemCode2 ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0      1900010101  FW380049-015  BK-0010E        NaN  1091.405184   29.195089
# 1      1900010102  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 2      1900010201  FW380049-015  BK-0010E        NaN  1637.107776    0.000000
# 3      1900010202  FW380049-015  BK-0010E        NaN   954.979536    0.000000
# 4      1900010301  FW380049-015   NU-0016  DYE_SG_LT  1705.320600   44.611187
# ...           ...           ...       ...        ...          ...         ...
# 16346  B204010101  FW380509-015       NaN        NaN     0.000000    0.000000
# 16347  B204020101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16348  B204030101  FK028082-012     BK/GR        NaN     0.000000    0.000000
# 16350  B204050101  FW380471-032       NaN        NaN     0.000000    0.000000
# 16351  B204050102  FW380471-032       NaN        NaN     0.000000    0.000000
#
# ...

# %%
df.ItemCode1.value_counts()
# Out:
# FK380028-008    1733
# FK048204-008    1582
# FW380026-014     770
# FK380334-010     322
# FK380052-008     275
#                 ...
# FW380001-012       3
# FK380402-040       2
# FK380334-009       2
# FW380427-010       1
# FJ101818-022       1
# Name: ItemCode1, Length: 327, dtype: int64
