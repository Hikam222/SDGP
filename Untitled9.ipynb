# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sas
from numpy.random import randint

# %%
df=pd.read_excel(r'C:\Users\dumindu yasa\Desktop\sdgp\DS\EWPS_beforeq2.xlsx')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#             JobNo  suffix              ItemCode ColorGroup       QtyCom  \
# 0      1900010101       0  FW380049-015BK-0010E        NaN  1116.717446
# 1      1900010101       0  FW380049-015BK-0010E        NaN     0.000000
# 2      1900010101       0  FW380049-015BK-0010E        NaN  1116.717446
# 3      1900010101       0  FW380049-015BK-0010E        NaN  1091.405184
# 4      1900010101       1          FW380049-015        NaN   123.290000
# ...           ...     ...                   ...        ...          ...
# 50673  B204060102       0       FJ086559-038/GR        NaN     0.000000
# 50674  B204060102       0       FJ086559-038/GR        NaN     0.000000
# 50675  B204060103       0       FJ086559-038/GR        NaN     0.000000
# 50676  B204060103       0       FJ086559-038/GR        NaN     0.000000
# 50677  B204060201       0       FJ086519-038/GR        NaN     0.000000
#
#          QtyScrp      WC  MtrWgt     itemcode1 itemcode2  wc1
# ...

# %%
newdf=pd.DataFrame({"JobNo":[],"ItemCode":[],"ColorGroup":[],"PK_QtyCom":[],"PK_QtyScrp":[],"QA_QtyCom":[],"QA_QtyScrp":[],"DYE_QtyCom":[],"DYE_QtyScrp":[],"KNT_QtyCom":[],"KNT_QtyScrp":[],"WEV_QtyCom":[],"WEV_QtyScrp":[],"WP_QtyCom":[],"WP_QtyScrp":[],"JAC_QtyCom":[],"JAC_QtyScrp":[],"Total_Quantity":[]})

# %%
mylist = []

for index1, row1 in df.head(n=50678).iterrows():
    mylist.append(row1.JobNo)

        
mylist = list(dict.fromkeys(mylist))
print(mylist)
# Out:
# ['1900010101', '1900010102', '1900010201', '1900010202', '1900010301', '1900010302', '1900010303', '1900010401', '1900010501', '1900010502', '1900010503', '1900010601', '1900010701', '1900010702', '1900010703', '1900010801', '1900010802', '1900010901', '1900011001', '1900011101', '1900011201', '1900011202', '1900011301', '1900011501', '1900011602', '1900011701', '1900011801', '1900011901', '1900012001', '1900012002', '1900012004', '1900020101', '1900030101', '1900030201', '1900030301', '1900030401', '1900040101', '1900040201', '1900050101', '1900060101', '1900070101', '1900130101', '1900150301', '1900180301', '1900180302', '1900180401', '1900180402', '1900180502', '1900180601', '1900180602', '1900180701', '1900190102', '1900190501', '1900190601', '1900190801', '1900191001', '1900191301', '1900191401', '1900191501', '1900200201', '1900200301', '1900210101', '1900210201', '1900210202', '1900210301', '1900210501', '1900210601', '1900210701', '1900220101', '1900250201', '1900250301', '19
# ...

# %%
df.wc1.value_counts()
# Out:
# PK     14468
# QA     14466
# DYE    12543
# KNT     4274
# WEV     2798
# WP      1744
# JAC      384
# PFT        1
# Name: wc1, dtype: int64

# %%
df[df.wc1=='PFT']
# Out:
#             JobNo  suffix             ItemCode ColorGroup  QtyCom  QtyScrp  \
# 44684  2019940101       0  FW380034-014BK-1784  DYE_SG_BK     0.0      0.0
#
#            WC  MtrWgt     itemcode1 itemcode2  wc1
# 44684  F1_PFT    3.08  FW380034-014   BK-1784  PFT

# %%
df=df[df.JobNo!='2019940101']

# %%
newdf=pd.DataFrame({"JobNo":[],"ItemCode":[],"ColorGroup":[],"PK_QtyCom":[],"PK_QtyScrp":[],"QA_QtyCom":[],"QA_QtyScrp":[],"DYE_QtyCom":[],"DYE_QtyScrp":[],"KNT_QtyCom":[],"KNT_QtyScrp":[],"WEV_QtyCom":[],"WEV_QtyScrp":[],"WP_QtyCom":[],"WP_QtyScrp":[],"JAC_QtyCom":[],"JAC_QtyScrp":[],"Total_Quantity":[]})

# %%
df
# Out:
#             JobNo  suffix              ItemCode ColorGroup       QtyCom  \
# 0      1900010101       0  FW380049-015BK-0010E        NaN  1116.717446
# 1      1900010101       0  FW380049-015BK-0010E        NaN     0.000000
# 2      1900010101       0  FW380049-015BK-0010E        NaN  1116.717446
# 3      1900010101       0  FW380049-015BK-0010E        NaN  1091.405184
# 4      1900010101       1          FW380049-015        NaN   123.290000
# ...           ...     ...                   ...        ...          ...
# 50673  B204060102       0       FJ086559-038/GR        NaN     0.000000
# 50674  B204060102       0       FJ086559-038/GR        NaN     0.000000
# 50675  B204060103       0       FJ086559-038/GR        NaN     0.000000
# 50676  B204060103       0       FJ086559-038/GR        NaN     0.000000
# 50677  B204060201       0       FJ086519-038/GR        NaN     0.000000
#
#          QtyScrp      WC  MtrWgt     itemcode1 itemcode2  wc1
# ...

# %%
df.ItemCode.value_counts()
# Out:
# FK380028-008BK-0042            963
# FK048204-008.5WH-1039          840
# FK048204-008.5BK-1142          765
# FK380028-008WH-0061            705
# FK380028-008TA-0059            594
#                               ...
# FK040176-006                     1
# FK103350-014                     1
# BMR-FW380162-030-FDCY000011      1
# BMR-FW380166-008-FSCY000003      1
# BMY-FW380003-011-51000026        1
# Name: ItemCode, Length: 3077, dtype: int64

# %%
newdf
# Out:
# Empty DataFrame
# Columns: [JobNo, ItemCode, ColorGroup, PK_QtyCom, PK_QtyScrp, QA_QtyCom, QA_QtyScrp, DYE_QtyCom, DYE_QtyScrp, KNT_QtyCom, KNT_QtyScrp, WEV_QtyCom, WEV_QtyScrp, WP_QtyCom, WP_QtyScrp, JAC_QtyCom, JAC_QtyScrp, Total_Quantity]
# Index: []

# %%
for i in mylist:
    
    print(i)
    JobNo=i
    ItemCode=''
    
    
    ColorGroup=''
    PK_QtyCom=0
    PK_QtyScrp=0
    QA_QtyCom=0
    QA_QtyScrp=0
    DYE_QtyCom=0
    DYE_QtyScrp=0
    KNT_QtyCom=0
    KNT_QtyScrp=0
    WEV_QtyCom=0
    WEV_QtyScrp=0
    WP_QtyCom=0
    WP_QtyScrp=0
    JAC_QtyCom=0
    JAC_QtyScrp=0
    Total_Quantity=0
    
    
    
    for index1, row1 in df[df.JobNo==i].iterrows():
        
        if(row1.wc1=="PK"):
            if(ItemCode==''):
                ItemCode=row1.ItemCode
                
            
            
            if(ColorGroup==''):
                ColorGroup=row1.ColorGroup
                
            if(Total_Quantity==0.00):
                Total_Quantity=row1.QtyCom
                
            PK_QtyCom=PK_QtyCom+row1.QtyCom
            PK_QtyScrp=PK_QtyScrp+row1.QtyScrp
            
        elif (row1.wc1=="QA"):
            if(ItemCode==''):
                ItemCode=row1.ItemCode
                
            
            
            if(ColorGroup==''):
                ColorGroup=row1.ColorGroup
                
            if(Total_Quantity==0.00):
                Total_Quantity=row1.QtyCom
                
            QA_QtyCom=QA_QtyCom+row1.QtyCom
            QA_QtyScrp=QA_QtyScrp+row1.QtyScrp
            
        elif (row1.wc1=="DYE"):
            if(ItemCode==''):
                ItemCode=row1.ItemCode
                
                
           
            
            if(ColorGroup==''):
                ColorGroup=row1.ColorGroup
                
            if(Total_Quantity==0.00):
                Total_Quantity=row1.QtyCom
                
            DYE_QtyCom=DYE_QtyCom+row1.QtyCom
            DYE_QtyScrp=DYE_QtyScrp+row1.QtyScrp
            
        elif (row1.wc1=="KNT"):
            if(ItemCode==''):
                ItemCode=row1.ItemCode
                
            
            
            if(ColorGroup==''):
                ColorGroup=row1.ColorGroup
                
            if(Total_Quantity==0.00):
                Total_Quantity=row1.QtyCom
                
            KNT_QtyCom=KNT_QtyCom+row1.QtyCom
            KNT_QtyScrp=KNT_QtyScrp+row1.QtyScrp
            
        elif (row1.wc1=="WEV"):
            if(ItemCode==''):
                ItemCode=row1.ItemCode
                
           
            if(ColorGroup==''):
                ColorGroup=row1.ColorGroup
                
            if(Total_Quantity==0.00):
                Total_Quantity=row1.QtyCom
                
            WEV_QtyCom=WEV_QtyCom+row1.QtyCom
            WEV_QtyScrp=WEV_QtyScrp+row1.QtyScrp
            
        
            
        elif (row1.wc1=="JAC"):
            if(ItemCode==''):
                ItemCode=row1.ItemCode
                
            if(Total_Quantity==0.00):
                Total_Quantity=row1.QtyCom
                
            
            
            if(ColorGroup==''):
                ColorGroup=row1.ColorGroup
                
            JAC_QtyCom=JAC_QtyCom+row1.QtyCom
            JAC_QtyScrp=JAC_QtyScrp+row1.QtyScrp
            
        elif (row1.wc1=="WP"):
            if(ItemCode==''):
                ItemCode=row1.ItemCode
                
            
            if(ColorGroup==''):
                ColorGroup=row1.ColorGroup
                
            if(Total_Quantity==0.00):
                Total_Quantity=row1.QtyCom
                
            WP_QtyCom=WP_QtyCom+row1.QtyCom
            WP_QtyScrp=WP_QtyScrp+row1.QtyScrp
        
        
    newdfdemo=pd.DataFrame({"JobNo":[JobNo],"ItemCode":[ItemCode],"ColorGroup":[ColorGroup],"PK_QtyCom":[PK_QtyCom],"PK_QtyScrp":[PK_QtyScrp],"QA_QtyCom":[QA_QtyCom],"QA_QtyScrp":[QA_QtyScrp],"DYE_QtyCom":[DYE_QtyCom],"DYE_QtyScrp":[DYE_QtyScrp],"KNT_QtyCom":[KNT_QtyCom],"KNT_QtyScrp":[KNT_QtyScrp],"WEV_QtyCom":[WEV_QtyCom],"WEV_QtyScrp":[WEV_QtyScrp],"WP_QtyCom":[WP_QtyCom],"WP_QtyScrp":[WP_QtyScrp],"JAC_QtyCom":[JAC_QtyCom],"JAC_QtyScrp":[JAC_QtyScrp],"Total_Quantity":[Total_Quantity]})
        
    newdf=newdf.append(newdfdemo)
# Out:
# 1900010101
# 1900010102
# 1900010201
# 1900010202
# 1900010301
# 1900010302
# 1900010303
# 1900010401
# 1900010501
# 1900010502
# 1900010503
# 1900010601
# 1900010701
# 1900010702
# 1900010703
# 1900010801
# 1900010802
# 1900010901
# 1900011001
# 1900011101
# 1900011201
# 1900011202
# 1900011301
# 1900011501
# 1900011602
# 1900011701
# 1900011801
# 1900011901
# 1900012001
# 1900012002
# 1900012004
# 1900020101
# 1900030101
# 1900030201
# 1900030301
# 1900030401
# 1900040101
# 1900040201
# 1900050101
# 1900060101
# 1900070101
# 1900130101
# 1900150301
# 1900180301
# 1900180302
# 1900180401
# 1900180402
# 1900180502
# 1900180601
# 1900180602
# 1900180701
# 1900190102
# 1900190501
# 1900190601
# 1900190801
# 1900191001
# 1900191301
# 1900191401
# 1900191501
# 1900200201
# 1900200301
# 1900210101
# 1900210201
# 1900210202
# 1900210301
# 1900210501
# 1900210601
# 1900210701
# 1900220101
# 1900250201
# 1900250301
# 1900250401
# 1900250501
# 1900250601
# 1900250701
# 1900250801
# ...

# %%
newdf
# Out:
#          JobNo              ItemCode ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0   1900010101  FW380049-015BK-0010E        NaN  1091.405184   29.195089
# 0   1900010102  FW380049-015BK-0010E        NaN   954.979536    0.000000
# 0   1900010201  FW380049-015BK-0010E        NaN  1637.107776    0.000000
# 0   1900010202  FW380049-015BK-0010E        NaN   954.979536    0.000000
# 0   1900010301   FW380049-015NU-0016  DYE_SG_LT  1705.320600   44.611187
# ..         ...                   ...        ...          ...         ...
# 0   B204050105          FW380471-032        NaN     0.000000    0.000000
# 0   B204060101       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060102       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060103       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060201       FJ086519-038/GR        NaN     0.000000    0.000000
#
#       QA_QtyCom  QA_QtyScrp   DYE_QtyCom  DYE_QtyScrp  KNT_QtyCom  \
# ...

# %%
df=newdf

# %%
df
# Out:
#          JobNo              ItemCode ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0   1900010101  FW380049-015BK-0010E        NaN  1091.405184   29.195089
# 0   1900010102  FW380049-015BK-0010E        NaN   954.979536    0.000000
# 0   1900010201  FW380049-015BK-0010E        NaN  1637.107776    0.000000
# 0   1900010202  FW380049-015BK-0010E        NaN   954.979536    0.000000
# 0   1900010301   FW380049-015NU-0016  DYE_SG_LT  1705.320600   44.611187
# ..         ...                   ...        ...          ...         ...
# 0   B204050105          FW380471-032        NaN     0.000000    0.000000
# 0   B204060101       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060102       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060103       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060201       FJ086519-038/GR        NaN     0.000000    0.000000
#
#       QA_QtyCom  QA_QtyScrp   DYE_QtyCom  DYE_QtyScrp  KNT_QtyCom  \
# ...

# %%
df[df['PK_QtyCom']==0.0][df['QA_QtyCom']==0.0][df['DYE_QtyCom']==0.0][df['KNT_QtyCom']==0.0][df['WEV_QtyCom']==0.0][df['WP_QtyCom']==0.0][df['JAC_QtyCom']==0.0]
# Out:
# <ipython-input-28-c55271b73002>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['PK_QtyCom']==0.0][df['QA_QtyCom']==0.0][df['DYE_QtyCom']==0.0][df['KNT_QtyCom']==0.0][df['WEV_QtyCom']==0.0][df['WP_QtyCom']==0.0][df['JAC_QtyCom']==0.0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-c55271b73002> in <module>
# ----> 1 df[df['PK_QtyCom']==0.0][df['QA_QtyCom']==0.0][df['DYE_QtyCom']==0.0][df['KNT_QtyCom']==0.0][df['WEV_QtyCom']==0.0][df['WP_QtyCom']==0.0][df['JAC_QtyCom']==0.0]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# ...

# %%
df
# Out:
#          JobNo              ItemCode ColorGroup    PK_QtyCom  PK_QtyScrp  \
# 0   1900010101  FW380049-015BK-0010E        NaN  1091.405184   29.195089
# 0   1900010102  FW380049-015BK-0010E        NaN   954.979536    0.000000
# 0   1900010201  FW380049-015BK-0010E        NaN  1637.107776    0.000000
# 0   1900010202  FW380049-015BK-0010E        NaN   954.979536    0.000000
# 0   1900010301   FW380049-015NU-0016  DYE_SG_LT  1705.320600   44.611187
# ..         ...                   ...        ...          ...         ...
# 0   B204050105          FW380471-032        NaN     0.000000    0.000000
# 0   B204060101       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060102       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060103       FJ086559-038/GR        NaN     0.000000    0.000000
# 0   B204060201       FJ086519-038/GR        NaN     0.000000    0.000000
#
#       QA_QtyCom  QA_QtyScrp   DYE_QtyCom  DYE_QtyScrp  KNT_QtyCom  \
# ...

# %%
newdf.to_excel("EWPS_part222.xlsx",sheet_name='Sheet_name_1')
