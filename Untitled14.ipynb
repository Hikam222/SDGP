# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn.metrics import mean_absolute_error
import joblib
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sas
from numpy.random import randint

# %%
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\dumindu yasa\Desktop\sdgp\DS\EWPS_data_with_waste_pecentage.xlsx')

# %%
df
# Out:
#        Unnamed: 0       JobNo              ItemCode ColorGroup    PK_QtyCom  \
# 0               0  1900010101  FW380049-015BK-0010E        NaN  1091.405184
# 1               1  1900010102  FW380049-015BK-0010E        NaN   954.979536
# 2               2  1900010201  FW380049-015BK-0010E        NaN  1637.107776
# 3               3  1900010202  FW380049-015BK-0010E        NaN   954.979536
# 4               4  1900010301   FW380049-015NU-0016  DYE_SG_LT  1705.320600
# ...           ...         ...                   ...        ...          ...
# 13492       16346  B204010101          FW380509-015        NaN     0.000000
# 13493       16347  B204020101     FK028082-012BK/GR        NaN     0.000000
# 13494       16348  B204030101     FK028082-012BK/GR        NaN     0.000000
# 13495       16350  B204050101          FW380471-032        NaN     0.000000
# 13496       16351  B204050102          FW380471-032        NaN     0.000000
#
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df = pd.get_dummies(df, columns=['ItemCode', 'ColorGroup'])

# %%
df
# Out:
#             JobNo    PK_QtyCom  PK_QtyScrp    QA_QtyCom  QA_QtyScrp  \
# 0      1900010101  1091.405184   29.195089  1116.717446         0.0
# 1      1900010102   954.979536    0.000000  1060.982265         0.0
# 2      1900010201  1637.107776    0.000000  1823.874488         0.0
# 3      1900010202   954.979536    0.000000   953.888131         0.0
# 4      1900010301  1705.320600   44.611187  2102.592087         0.0
# ...           ...          ...         ...          ...         ...
# 13492  B204010101     0.000000    0.000000     0.000000         0.0
# 13493  B204020101     0.000000    0.000000     0.000000         0.0
# 13494  B204030101     0.000000    0.000000     0.000000         0.0
# 13495  B204050101     0.000000    0.000000     0.000000         0.0
# 13496  B204050102     0.000000    0.000000     0.000000         0.0
#
#         DYE_QtyCom  DYE_QtyScrp  KNT_QtyCom  KNT_QtyScrp  WEV_QtyCom  ...  \
# 0      1116.717446          0.0        0.00         0.00        0.00  ...
# ...

# %%
df.describe()
# Out:
#            PK_QtyCom    PK_QtyScrp      QA_QtyCom    QA_QtyScrp  \
# count   13497.000000  13497.000000   13497.000000  13497.000000
# mean     4934.894503      2.277116    5132.606312      0.346734
# std     15376.257463     61.284555   15541.779087     16.137714
# min         0.000000      0.000000       0.000000      0.000000
# 25%        77.235772      0.000000      74.101519      0.000000
# 50%       815.420561      0.000000     842.105263      0.000000
# 75%      3982.142857      0.000000    4209.923075      0.000000
# max    418736.480687   4127.100073  420726.180258   1384.736842
#
#           DYE_QtyCom   DYE_QtyScrp    KNT_QtyCom   KNT_QtyScrp    WEV_QtyCom  \
# count   13497.000000  13497.000000  13497.000000  13497.000000  13497.000000
# mean     3931.357502     63.602593     35.513587      2.269326     15.163305
# std      8875.962633    429.530222    148.780481     10.238279     75.675512
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# ...

# %%
df.PK_QtyCom.hist()
# Out:
# <AxesSubplot:>

# %%
df.waste_pecentage.hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='waste_pecentage')
# Out:
# <AxesSubplot:>

# %%
df[['Total_Quantity','waste_pecentage','ColorGroup_DYE_SG_BK','ColorGroup_DYE_SG_DK','ColorGroup_DYE_SG_FI','ColorGroup_DYE_SG_LT','ColorGroup_DYE_SG_MD','ColorGroup_DYE_SG_WH']].corr()
# Out:
#                       Total_Quantity  waste_pecentage  ColorGroup_DYE_SG_BK  \
# Total_Quantity              1.000000        -0.002926              0.103214
# waste_pecentage            -0.002926         1.000000             -0.003027
# ColorGroup_DYE_SG_BK        0.103214        -0.003027              1.000000
# ColorGroup_DYE_SG_DK       -0.035052         0.029380             -0.103015
# ColorGroup_DYE_SG_FI       -0.001157        -0.003883             -0.158604
# ColorGroup_DYE_SG_LT       -0.010796        -0.003835             -0.156634
# ColorGroup_DYE_SG_MD       -0.003829        -0.003510             -0.143362
# ColorGroup_DYE_SG_WH        0.060229        -0.002860             -0.116830
#
#                       ColorGroup_DYE_SG_DK  ColorGroup_DYE_SG_FI  \
# Total_Quantity                   -0.035052             -0.001157
# waste_pecentage                   0.029380             -0.003883
# ColorGroup_DYE_SG_BK             -0.103015             -0.158604
# ...

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)


sns.heatmap(df[['Total_Quantity','waste_pecentage','ColorGroup_DYE_SG_BK','ColorGroup_DYE_SG_DK','ColorGroup_DYE_SG_FI','ColorGroup_DYE_SG_LT','ColorGroup_DYE_SG_MD','ColorGroup_DYE_SG_WH']].corr(),  cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
